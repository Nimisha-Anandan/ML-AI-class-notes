# %%
import pandas as pd

# %%
data = pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\Nimisha.Anandan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data.shape
# Out:
# (45466, 24)

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
data = data[[ 'revenue', 'title','vote_average', 'vote_count','runtime']]

# %% [markdown]
# v - no.of votes generated by the movie
# c - mean rating of the perticuar data
# R - mean rating of the movie
# m - mini no. of votes required for the movie to be in the chart

# %%
c = data['vote_average'].mean()

# %%
m = data['vote_count'].quantile(0.9)
m
# Out:
# 160.0

# %%
data['runtime'].min()
# Out:
# 0.0

# %%
data['runtime'].max()
# Out:
# 1256.0

# %%
filt_movies = data[(data['runtime']>=60) & (data['runtime'] <=300)]

# %%
filt_movies = filt_movies[filt_movies['vote_count']>= m]

# %%
filt_movies.shape
# Out:
# (4511, 5)

# %%
def weighted_rating(x, m = m, c = c):
    v = x['vote_count']
    R = x['vote_average']
    wgt_rating = (v/(v+m) * R) + (m/(m+v) * c)
    return wgt_rating

# %%
filt_movies['score']=filt_movies.apply(weighted_rating, axis=1)

# %%
filt_movies
# Out:
#            revenue                        title  vote_average  vote_count  \
# 0      373554033.0                    Toy Story           7.7      5415.0
# 1      262797249.0                      Jumanji           6.9      2413.0
# 4       76578911.0  Father of the Bride Part II           5.7       173.0
# 5      187436818.0                         Heat           7.7      1886.0
# 8       64350171.0                 Sudden Death           5.5       174.0
# ...            ...                          ...           ...         ...
# 45177          0.0                      Brice 3           4.3       160.0
# 45204          0.0                   Girls Trip           7.1       393.0
# 45258          0.0                Descendants 2           7.5       171.0
# 45265    1359497.0                Force Majeure           6.8       255.0
# 45343          0.0   The Visitors: Bastille Day           4.0       167.0
#
#        runtime     score
# 0         81.0  7.640253
# 1        104.0  6.820293
# ...

# %%
filt_movies = filt_movies.sort_values("score",ascending=False)

# %%
filt_movies[['title','vote_average','score']].head(20)
# Out:
#                                  title  vote_average     score
# 314           The Shawshank Redemption           8.5  8.445869
# 834                      The Godfather           8.5  8.425439
# 10309      Dilwale Dulhania Le Jayenge           9.1  8.421453
# 12481                  The Dark Knight           8.3  8.265477
# 2843                        Fight Club           8.3  8.256385
# 292                       Pulp Fiction           8.3  8.251406
# 522                   Schindler's List           8.3  8.206639
# 23673                         Whiplash           8.3  8.205404
# 5481                     Spirited Away           8.3  8.196055
# 2211                 Life Is Beautiful           8.3  8.187171
# 1178            The Godfather: Part II           8.3  8.180076
# 1152   One Flew Over the Cuckoo's Nest           8.3  8.164256
# 351                       Forrest Gump           8.2  8.150272
# 1154           The Empire Strikes Back           8.2  8.132919
# ...
